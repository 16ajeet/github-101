# %%
## ==========important imports ==================================
import os
import pandas as pd
import numpy as np

# %% [markdown]
# * for making directory we use **!mkdir -p directory_name**.
# -p stands for parent directory. we use it so if parent directory dont exist then create it or if it exists then create inside it.
# * for creating files we use **%%writefile** **path/file_name.py**

# %%
## =============== making directories =================================
# !mkdir -p src
# !mkdir -p models
# !mkdir -p data
# !ls
# Out:
# data  models  __notebook__.ipynb  src

# %%
# %%writefile src/preprocessing.py
print("this is preprocessing")
# Out:
# Writing src/preprocessing.py

# %%
# %%writefile src/training.py
print("this is training file")
# Out:
# Writing src/training.py

# %%
# %%writefile src/model.py
print("this is model file")
# Out:
# Writing src/model.py

# %%
# %%writefile src/__init__.py
print("this is entry file")
# Out:
# Writing src/__init__.py

# %%
# !ls
# Out:
# data  models  __notebook__.ipynb  src

# %%
# %%writefile requirement.txt
# pandas
# numpy
# scikit-learn
# Out:
# Writing requirement.txt
